# %% [markdown]
# <a href="https://colab.research.google.com/github/aabiskardahal15-jpg/Mathworkshop/blob/main/workshop8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1

# %%
import numpy as np

matrix1 = np.random.randint(0, 10, size=(5, 6))

matrix2 = np.random.randint(0, 10, size=(5, 6))

result_matrix = matrix1 + matrix2

print("Matrix 1:")
print(matrix1)

print("\nMatrix 2:")
print(matrix2)

print("\nResult Matrix (Matrix 1 + Matrix 2):")
print(result_matrix)
# Out:
# Matrix 1:
# [[0 2 9 4 9 0]
#  [0 9 3 7 1 5]
#  [8 1 9 1 3 5]
#  [3 4 6 7 1 9]
#  [9 4 5 8 8 3]]
#
# Matrix 2:
# [[0 5 9 3 8 2]
#  [1 8 7 6 9 2]
#  [3 7 7 0 4 3]
#  [7 9 3 2 7 5]
#  [7 7 1 5 4 1]]
#
# Result Matrix (Matrix 1 + Matrix 2):
# [[ 0  7 18  7 17  2]
#  [ 1 17 10 13 10  7]
#  [11  8 16  1  7  8]
#  [10 13  9  9  8 14]
#  [16 11  6 13 12  4]]

# %% [markdown]
# Task 2

# %%
import numpy as np

matrix_a = np.random.randint(0, 10, size=(2, 3))

matrix_b = np.random.randint(0, 10, size=(2, 3))

matrix_c = np.random.randint(0, 10, size=(2, 3))

result_matrix_new = (matrix_a - matrix_b) + matrix_c

print("Matrix A:")
print(matrix_a)

print("\nMatrix B:")
print(matrix_b)

print("\nMatrix C:")
print(matrix_c)

print("\nResult Matrix (A - B + C):")
print(result_matrix_new)
# Out:
# Matrix A:
# [[1 4 5]
#  [2 2 3]]
#
# Matrix B:
# [[7 4 2]
#  [2 8 2]]
#
# Matrix C:
# [[4 1 5]
#  [0 0 1]]
#
# Result Matrix (A - B + C):
# [[-2  1  8]
#  [ 0 -6  2]]

# %% [markdown]
# Task 3

# %%
import numpy as np

matrix = np.random.randint(1, 21, size=(4, 4))
print("Generated 4x4 Matrix:")
print(matrix)

while True:
    try:
        user_number_str = input("\nEnter a number to check if it's in the matrix (1-20): ")
        user_number = int(user_number_str)
        if 1 <= user_number <= 20:
            break # Exit loop if input is valid
        else:
            print("Please enter a number between 1 and 20.")
    except ValueError:
        print("Invalid input. Please enter an integer.")

if user_number in matrix:
    count = np.count_nonzero(matrix == user_number)
    print(f"\nThe number {user_number} is in the matrix. It appears {count} time(s).")
else:
    print(f"\nThe number {user_number} is NOT in the matrix.")
# Out:
# Generated 4x4 Matrix:
# [[12  9 19 19]
#  [ 8 14  2 11]
#  [ 7  1 19  8]
#  [20 15 19 18]]
#
# Enter a number to check if it's in the matrix (1-20): 7
#
# The number 7 is in the matrix. It appears 1 time(s).

# %% [markdown]
# Task 4

# %%
import numpy as np

A = np.random.randint(0, 10, size=(5, 5))
print("Matrix A:")
print(A)

rank_A = np.linalg.matrix_rank(A)
print(f"\nRank of Matrix A: {rank_A}")

if rank_A == 5:
    print("Matrix A is invertible because its rank is equal to its dimension (5).")
else:
    print("Matrix A is not invertible because its rank is less than its dimension (5).")
# Out:
# Matrix A:
# [[2 8 0 0 0]
#  [3 7 2 1 1]
#  [9 8 0 4 3]
#  [2 8 0 1 7]
#  [7 0 8 5 3]]
#
# Rank of Matrix A: 5
# Matrix A is invertible because its rank is equal to its dimension (5).

# %% [markdown]
# Task 5

# %%
import numpy as np

A = np.random.randint(0, 10, size=(5, 5))
print("Matrix A:")
print(A)

x_true = np.random.randint(0, 10, size=(5, 1))
print("\nTrue Vector x:")
print(x_true)

b = np.dot(A, x_true)
print("\nVector b (A * x_true):")
print(b)

x_solved = np.linalg.solve(A, b)
print("\nSolved Vector x:")
print(x_solved)

print("\nVerification (x_true == x_solved):")
print(np.allclose(x_true, x_solved))
# Out:
# Matrix A:
# [[5 7 1 1 4]
#  [4 6 5 6 4]
#  [0 4 1 5 4]
#  [4 6 0 3 8]
#  [1 1 9 4 5]]
#
# True Vector x:
# [[4]
#  [0]
#  [0]
#  [4]
#  [2]]
#
# Vector b (A * x_true):
# [[32]
#  [48]
#  [28]
#  [44]
#  [30]]
#
# Solved Vector x:
# [[4.00000000e+00]
#  [1.47697086e-15]
#  [1.19754394e-15]
#  [4.00000000e+00]
#  [2.00000000e+00]]
#
# Verification (x_true == x_solved):
# True

# %% [markdown]
# Task 6

# %%
import numpy as np

A_system = np.array([
    [8, 3, -2],
    [-4, 7, 5],
    [3, 4, -12]
])

b_system = np.array([
    [9],
    [15],
    [35]
])

print("Coefficient Matrix A:")
print(A_system)
print("\nConstant Vector b:")
print(b_system)

solution = np.linalg.solve(A_system, b_system)

print("\nSolution (x, y, z):")
print(solution)

x_val, y_val, z_val = solution.flatten()
print(f"\nx = {x_val:.4f}")
print(f"y = {y_val:.4f}")
print(f"z = {z_val:.4f}")
# Out:
# Coefficient Matrix A:
# [[  8   3  -2]
#  [ -4   7   5]
#  [  3   4 -12]]
#
# Constant Vector b:
# [[ 9]
#  [15]
#  [35]]
#
# Solution (x, y, z):
# [[-0.58226371]
#  [ 3.22870478]
#  [-1.98599767]]
#
# x = -0.5823
# y = 3.2287
# z = -1.9860

# %% [markdown]
# Task 7

# %%
import numpy as np
import matplotlib.pyplot as plt

x_points = np.array([-3, -2, -1, 0, 1, 2, 3, 4, 5, 7])
y_points = np.array([-7.6, 1, 4.8, 5, 2.8, -0.6, -4, -6.2, -6, 6.4])

# Plot the points
plt.figure(figsize=(10, 6))
plt.plot(x_points, y_points, 'o-', label='Given Points')
plt.title('Given Points in X-Y Plane')
plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
plt.legend()
plt.show()
